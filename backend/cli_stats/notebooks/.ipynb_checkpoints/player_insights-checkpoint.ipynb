# %%
import os
import pymongo
import pandas as pd
from functools import reduce
import requests
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt  # To visualize
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from pymongo import MongoClient
import statsmodels.api as sm

# %%
class DBConn():

    def __init__(self, DB_NAME='PremierLeague'):
        self.db_user = os.environ.get('DB_user')
        self.db_pass = os.environ.get('DB_pass')
        self.MONGODB_URL = f'mongodb+srv://{self.db_user}:{self.db_pass}@cluster0-mbqxj.mongodb.net/<dbname>?retryWrites=true&w=majority'
        self.client = MongoClient(self.MONGODB_URL)
        self.DATABASE = self.client[DB_NAME]

# %%
"""Get pass stats"""
db = DBConn()
coll = db.DATABASE['fixture_info']
pipeline = [
    {
        '$match':{
            'seasonId': 363,
            '$and': [
                { 'status': {'$eq': 'C'} }
            ],
        },
    },
    {
        '$project':{
            '_id': 0,
            'fId': 1,
            'formation': 1,
            'lineUps': 1,
            'substitutes': 1 
        },  
    },
    {
        '$limit': 1
    },
]
stats_query = list(coll.aggregate(pipeline))
pprint(stats_query)
# Out:
# [{'fId': 58898,
#   'formation': [{'label': '4-2-3-1',
#                  'players': [[10727],
#                              [12536, 4582, 4276, 8185],
#                              [4818, 3894],
#                              [20178, 7490, 5079],
#                              [11267]],
#                  'teamId': 34},
#                 {'label': '3-4-3',
#                  'players': [[4985],
#                              [11575, 50234, 12185],
#                              [4474, 5239, 12136, 10428],
#                              [4748, 6899, 5110]],
#                  'teamId': 1}],
#   'lineUps': [{'captain': False,
#                'first': 'Joe',
#                'id': 8185,
#                'last': 'Bryan',
#                'matchPosition': 'D',
#                'name': 'Joe Bryan',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Left Full Back',
#                'shirtNum': 23,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Josh',
#                'id': 7490,
#                'last': 'Onomah',
#                'matchPosition': 'M',
#                'name': 'Josh Onomah',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Left/Centre/Right Attacking Midfielder',
#                'shirtNum': 25,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Ivan',
#                'id': 5079,
#                'last': 'Cavaleiro',
#                'matchPosition': 'M',
#                'name': 'Ivan Cavaleiro',
#                'playerId': 0,
#                'position': 'F',
#                'positionInfo': 'Left/Right Winger',
#                'shirtNum': 17,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Marek',
#                'id': 10727,
#                'last': 'Rodák',
#                'matchPosition': 'G',
#                'name': 'Marek Rodák',
#                'playerId': 0,
#                'position': 'G',
#                'positionInfo': 'Goalkeeper',
#                'shirtNum': 12,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Aboubakar',
#                'id': 11267,
#                'last': 'Kamara',
#                'matchPosition': 'F',
#                'name': 'Aboubakar Kamara',
#                'playerId': 0,
#                'position': 'F',
#                'positionInfo': 'Centre Striker',
#                'shirtNum': 47,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Denis',
#                'id': 12536,
#                'last': 'Odoi',
#                'matchPosition': 'D',
#                'name': 'Denis Odoi',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Right Full Back',
#                'shirtNum': 4,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Michael',
#                'id': 4582,
#                'last': 'Hector',
#                'matchPosition': 'D',
#                'name': 'Michael Hector',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Centre Central Defender',
#                'shirtNum': 3,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Tim',
#                'id': 4276,
#                'last': 'Ream',
#                'matchPosition': 'D',
#                'name': 'Tim Ream',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Left/Centre Central Defender',
#                'shirtNum': 13,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Neeskens',
#                'id': 20178,
#                'last': 'Kebano',
#                'matchPosition': 'M',
#                'name': 'Neeskens Kebano',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Left/Centre/Right Attacking Midfielder',
#                'shirtNum': 7,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Harrison',
#                'id': 4818,
#                'last': 'Reed',
#                'matchPosition': 'M',
#                'name': 'Harrison Reed',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Centre Central Midfielder',
#                'shirtNum': 21,
#                'teamId': 34},
#               {'captain': True,
#                'first': 'Tom',
#                'id': 3894,
#                'last': 'Cairney',
#                'matchPosition': 'M',
#                'name': 'Tom Cairney',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Left/Centre/Right Attacking Midfielder',
#                'shirtNum': 10,
#                'teamId': 34},
#               {'captain': False,
#                'first': 'Rob',
#                'id': 11575,
#                'last': 'Holding',
#                'matchPosition': 'D',
#                'name': 'Rob Holding',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Centre Central Defender',
#                'shirtNum': 16,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Alexandre',
#                'id': 6899,
#                'last': 'Lacazette',
#                'matchPosition': 'F',
#                'name': 'Alexandre Lacazette',
#                'playerId': 0,
#                'position': 'F',
#                'positionInfo': 'Centre Striker',
#                'shirtNum': 9,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Willian',
#                'id': 4748,
#                'last': 'Borges Da Silva',
#                'matchPosition': 'F',
#                'name': 'Willian',
#                'playerId': 0,
#                'position': 'F',
#                'positionInfo': 'Left/Centre/Right Winger',
#                'shirtNum': 12,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Granit',
#                'id': 12136,
#                'last': 'Xhaka',
#                'matchPosition': 'M',
#                'name': 'Granit Xhaka',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Centre Central Midfielder',
#                'shirtNum': 34,
#                'teamId': 1},
#               {'captain': True,
#                'first': 'Pierre-Emerick',
#                'id': 5110,
#                'last': 'Aubameyang',
#                'matchPosition': 'F',
#                'name': 'Pierre-Emerick Aubameyang',
#                'playerId': 0,
#                'position': 'F',
#                'positionInfo': 'Centre Striker',
#                'shirtNum': 14,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Mohamed Naser',
#                'id': 5239,
#                'last': 'El Sayed Elneny',
#                'matchPosition': 'M',
#                'name': 'Mohamed Elneny',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Centre Defensive Midfielder',
#                'shirtNum': 25,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Gabriel',
#                'id': 50234,
#                'last': 'dos Santos Magalhães',
#                'matchPosition': 'D',
#                'name': 'Gabriel Magalhães',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Centre Central Defender',
#                'shirtNum': 6,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Héctor',
#                'id': 4474,
#                'last': 'Bellerín',
#                'matchPosition': 'M',
#                'name': 'Héctor Bellerín',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Right Full Back',
#                'shirtNum': 2,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Ainsley',
#                'id': 10428,
#                'last': 'Maitland-Niles',
#                'matchPosition': 'M',
#                'name': 'Ainsley Maitland-Niles',
#                'playerId': 0,
#                'position': 'M',
#                'positionInfo': 'Left Wing Back',
#                'shirtNum': 15,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Bernd',
#                'id': 4985,
#                'last': 'Leno',
#                'matchPosition': 'G',
#                'name': 'Bernd Leno',
#                'playerId': 0,
#                'position': 'G',
#                'positionInfo': 'Goalkeeper',
#                'shirtNum': 1,
#                'teamId': 1},
#               {'captain': False,
#                'first': 'Kieran',
#                'id': 12185,
#                'last': 'Tierney',
#                'matchPosition': 'D',
#                'name': 'Kieran Tierney',
#                'playerId': 0,
#                'position': 'D',
#                'positionInfo': 'Left Full Back',
#                'shirtNum': 3,
#                'teamId': 1}],
#   'substitutes': [{'captain': False,
#                    'first': 'Aleksandar',
#                    'id': 5879,
#                    'last': 'Mitrovic',
#                    'matchPosition': 'F',
#                    'name': 'Aleksandar Mitrovic',
#                    'playerId': 0,
#                    'position': 'F',
#                    'positionInfo': 'Centre Striker',
#                    'shirtNum': 9,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Alphonse',
#                    'id': 5748,
#                    'last': 'Areola',
#                    'matchPosition': 'G',
#                    'name': 'Alphonse Areola',
#                    'playerId': 0,
#                    'position': 'G',
#                    'positionInfo': 'Goalkeeper',
#                    'shirtNum': 1,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Bobby',
#                    'id': 8192,
#                    'last': 'De Cordova-Reid',
#                    'matchPosition': 'F',
#                    'name': 'Bobby De Cordova-Reid',
#                    'playerId': 0,
#                    'position': 'F',
#                    'positionInfo': 'Centre Striker',
#                    'shirtNum': 14,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'André-Frank',
#                    'id': 32162,
#                    'last': 'Zambo Anguissa',
#                    'matchPosition': 'M',
#                    'name': 'André-Frank Zambo Anguissa',
#                    'playerId': 0,
#                    'position': 'M',
#                    'positionInfo': 'Centre Central Midfielder',
#                    'shirtNum': 29,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Anthony',
#                    'id': 8982,
#                    'last': 'Knockaert',
#                    'matchPosition': 'M',
#                    'name': 'Anthony Knockaert',
#                    'playerId': 0,
#                    'position': 'M',
#                    'positionInfo': 'Left/Centre/Right Attacking Midfielder',
#                    'shirtNum': 24,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Maxime',
#                    'id': 20503,
#                    'last': 'Le Marchand',
#                    'matchPosition': 'D',
#                    'name': 'Maxime Le Marchand',
#                    'playerId': 0,
#                    'position': 'D',
#                    'positionInfo': 'Centre Central Defender',
#                    'shirtNum': 20,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Cyrus',
#                    'id': 8438,
#                    'last': 'Christie',
#                    'matchPosition': 'D',
#                    'name': 'Cyrus Christie',
#                    'playerId': 0,
#                    'position': 'D',
#                    'positionInfo': 'Right Full Back',
#                    'shirtNum': 22,
#                    'teamId': 34},
#                   {'captain': False,
#                    'first': 'Nicolas',
#                    'id': 50252,
#                    'last': 'Pépé',
#                    'matchPosition': 'F',
#                    'name': 'Nicolas Pépé',
#                    'playerId': 0,
#                    'position': 'F',
#                    'positionInfo': 'Right Winger',
#                    'shirtNum': 19,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Matt',
#                    'id': 10422,
#                    'last': 'Macey',
#                    'matchPosition': 'G',
#                    'name': 'Matt Macey',
#                    'playerId': 0,
#                    'position': 'G',
#                    'positionInfo': 'Goalkeeper',
#                    'shirtNum': 33,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Bukayo',
#                    'id': 49481,
#                    'last': 'Saka',
#                    'matchPosition': 'M',
#                    'name': 'Bukayo Saka',
#                    'playerId': 0,
#                    'position': 'M',
#                    'positionInfo': 'Left Winger',
#                    'shirtNum': 7,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Eddie',
#                    'id': 14451,
#                    'last': 'Nketiah',
#                    'matchPosition': 'F',
#                    'name': 'Eddie Nketiah',
#                    'playerId': 0,
#                    'position': 'F',
#                    'positionInfo': 'Centre Striker',
#                    'shirtNum': 30,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Dani',
#                    'id': 7163,
#                    'last': 'Ceballos',
#                    'matchPosition': 'M',
#                    'name': 'Dani Ceballos',
#                    'playerId': 0,
#                    'position': 'M',
#                    'positionInfo': 'Left/Centre/Right Attacking Midfielder',
#                    'shirtNum': 8,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Sead',
#                    'id': 5368,
#                    'last': 'Kolasinac',
#                    'matchPosition': 'D',
#                    'name': 'Sead Kolasinac',
#                    'playerId': 0,
#                    'position': 'D',
#                    'positionInfo': 'Left Full Back',
#                    'shirtNum': 31,
#                    'teamId': 1},
#                   {'captain': False,
#                    'first': 'Joseph',
#                    'id': 14446,
#                    'last': 'Willock',
#                    'matchPosition': 'M',
#                    'name': 'Joseph Willock',
#                    'playerId': 0,
#                    'position': 'M',
#                    'positionInfo': 'Centre Central Midfielder',
#                    'shirtNum': 28,
#                    'teamId': 1}]}]

# %%
df = pd.DataFrame.from_records(stats_query)

# %%
lineups = pd.concat([pd.DataFrame(x) for x in df['lineUps']], keys=df['fId']).reset_index(level=1, drop=True).reset_index() 
lineups['start'] = 1

# %%
formation = pd.concat([pd.DataFrame(x) for x in df['formation']], keys=df['fId']).reset_index(level=1, drop=True).reset_index()
formation = formation.drop('players', axis=1)

# %%
substitutes = pd.concat([pd.DataFrame(x) for x in df['substitutes']], keys=df['fId']).reset_index(level=1, drop=True).reset_index() 
substitutes['sub'] = 1

# %%
data = lineups.append(substitutes)
data = pd.merge(data, formation, how='left', on=['fId', 'teamId'])

# %%
games = data.drop_duplicates(subset=['fId','teamId'])
games = games[['fId','teamId']]

# %%
def get_stats(fId, teamId):
    db = DBConn()
    coll = db.DATABASE['fixture_stats']
    pipeline = [
        {
            '$match':{
                'fId': int(fId),
            },
        },
        {
            '$project': {
                '_id': 0
            }
        }
    ]
    stats_query = list(coll.aggregate(pipeline))
    return stats_query

# %%
df = pd.DataFrame()
for index, row in games.iterrows():
    fId = row['fId']
    teamId = row['teamId']
    data = get_stats(fId, teamId)
    df = df.append(data)
df
# Out:
#                         _id    fId  seasonId teamId  accurate_back_zone_pass  \
# 0  603a0a6e7c321f6ec8f1b5ca  58898       363     34                    246.0
# 0  603a0a6e7c321f6ec8f1b5ce  58898       363      1                    367.0
#
#    accurate_chipped_pass  accurate_cross  accurate_cross_nocorner  \
# 0                   13.0             2.0                      2.0
# 0                   16.0             4.0                      2.0
#
#    accurate_flick_on  accurate_fwd_zone_pass  ...  goals  goals_openplay  \
# 0                1.0                   217.0  ...    NaN             NaN
# 0                NaN                   199.0  ...    3.0             2.0
#
#    hand_ball  hit_woodwork  offtarget_att_assist  overrun  post_scoring_att  \
# 0        NaN           NaN                   NaN      NaN               NaN
# 0        1.0           1.0                   2.0      1.0               1.0
#
#    saved_obox  total_through_ball  wins
# 0         NaN                 NaN   NaN
# 0         2.0                 2.0   1.0
#
# [2 rows x 182 columns]
